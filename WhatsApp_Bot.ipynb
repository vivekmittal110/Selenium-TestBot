# %%
import time
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

service = Service("C:/Users/91931/Downloads/chromedriver-win64/chromedriver-win64/chromedriver.exe")
driver = webdriver.Chrome(service=service)

driver.get("https://web.whatsapp.com")
print("Please scan the QR code within 20 seconds.")
time.sleep(20)


def find_and_send_keys(xpath, keys):
    time.sleep(2)  # Wait for element to be interactable
    element = driver.find_element(By.XPATH, xpath)
    element.send_keys(keys)
    return element

def send_message_to_contact(name, message):
    # Search for the contact
    search_box = find_and_send_keys('//*[@id="side"]/div[1]/div/div[2]/div[2]/div/div[1]', name + Keys.ENTER)
    time.sleep(2)  # Wait for search results
    
    # Send the message
    message_box = find_and_send_keys('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]', message)
    send_button = driver.find_element(By.XPATH, '//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[2]/button').click()
    time.sleep(1)  # Wait for message to send

def send_messages_to_multiple_contacts(contacts, message):
    for contact in contacts:
        try:
            send_message_to_contact(contact, message)
            print(f"Message sent to {contact}")
        except Exception as e:
            print(f"Failed to send message to {contact}. Error: {str(e)}")


# Pending some content
def send{nothing]:
         working on this bot
# List of contacts to send messages to
contacts = ["Nitin New", "Krishna"]  # Add more contacts as needed

# Message to send
message = "Hi! This is an autogenerated message."

# Send messages to multiple contacts
send_messages_to_multiple_contacts(contacts, message)

print("All messages sent. Press Enter to exit.")
input()

driver.quit()
# Out:
# Please scan the QR code within 20 seconds.
# Failed to send message to Prashant. Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="side"]/div[1]/div/div[2]/div[2]/div/div[1]"}
#   (Session info: chrome=131.0.6778.265); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF7BE8E2775+28773]
# 	(No symbol) [0x00007FF7BE84AFB0]
# 	(No symbol) [0x00007FF7BE6E552A]
# 	(No symbol) [0x00007FF7BE738EAE]
# 	(No symbol) [0x00007FF7BE73919C]
# 	(No symbol) [0x00007FF7BE7823F7]
# 	(No symbol) [0x00007FF7BE75EFDF]
# 	(No symbol) [0x00007FF7BE77F1A4]
# 	(No symbol) [0x00007FF7BE75ED43]
# 	(No symbol) [0x00007FF7BE72A548]
# 	(No symbol) [0x00007FF7BE72B6B1]
# 	GetHandleVerifier [0x00007FF7BEC0F45D+3358029]
# 	GetHandleVerifier [0x00007FF7BEC2430D+3443709]
# 	GetHandleVerifier [0x00007FF7BEC183FD+3394797]
# 	GetHandleVerifier [0x00007FF7BE9A929B+842635]
# 	(No symbol) [0x00007FF7BE85654F]
# 	(No symbol) [0x00007FF7BE851FA4]
# 	(No symbol) [0x00007FF7BE85213D]
# 	(No symbol) [0x00007FF7BE841629]
# 	BaseThreadInitThunk [0x00007FFDEB47259D+29]
# 	RtlUserThreadStart [0x00007FFDEBF0AF38+40]
#
# Failed to send message to hrithik. Error: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="side"]/div[1]/div/div[2]/div[2]/div/div[1